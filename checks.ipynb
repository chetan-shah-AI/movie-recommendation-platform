# %%
import pandas as pd

df = pd.read_parquet("artifacts/train_data.parquet")
print(df.columns)
print(df.head())
# Out:
# Index(['user_id', 'movie_id', 'rating', 'timestamp'], dtype='str')
#    user_id  movie_id  rating   timestamp
# 0   161935      2324     5.0  1664580315
# 1    23152    134130     5.0  1611918304
# 2   152931      4357     4.5  1114440842
# 3   177271    111622     4.5  1667236702
# 4   167551      5378     3.5  1064024402

# %%
import joblib

model = joblib.load("artifacts/svd_model.pkl")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[3], line 3
#       1 import joblib
#       2
# ----> 3 model = joblib.load("artifacts/svd_model.pkl")
#
# File ~/Documents/GitHub/movie-recommendation-platform/.venv/lib/python3.12/site-packages/joblib/numpy_pickle.py:735, in load(filename, mmap_mode, ensure_native_byte_order)
#     733         obj = _unpickle(fobj, ensure_native_byte_order=ensure_native_byte_order)
#     734 else:
# --> 735     with open(filename, "rb") as f:
#     736         with _validate_fileobject_and_memmap(f, filename, mmap_mode) as (
#     737             fobj,
#     738             validated_mmap_mode,
#     739         ):
#     740             if isinstance(fobj, str):
#     741                 # if the returned file object is a string, this means we
#     742                 # try to load a pickle file generated with an version of
# ...
